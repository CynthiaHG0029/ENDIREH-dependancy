# %%
import pandas as pd
import re

# %%
df = pd.read_csv('./resultMelt2.csv', encoding='latin-1')
df
# Out:
#         Unnamed: 0  Edad Identificador de la mujer  \
# 0                0    32           0100003.01.1.02
# 1                1    74           0100003.02.1.02
# 2                2    70           0100003.03.1.03
# 3                3    24           0100003.05.1.02
# 4                4    61           0100004.01.1.02
# ...            ...   ...                       ...
# 770884      770884    64           3260787.14.1.02
# 770885      770885    40           3260787.15.1.02
# 770886      770886    78           3260787.16.1.01
# 770887      770887    69           3260787.17.1.02
# 770888      770888    18           3260787.18.1.03
#
#         Identificador de vivienda seleccionada  \
# 0                                    100003.01
# 1                                    100003.02
# 2                                    100003.03
# 3                                    100003.05
# 4                                    100004.01
# ...                                        ...
# ...

# %% [markdown]
# Hacer rango de edades

# %%
df['rango_edad']=pd.cut(df.Edad, 8, precision=0, right=False, labels=["De 15 a 25", "De 26 a 36", "De 37 a 46", "De 47 a 56", "De 57 a 67", "De 68 a 77", "De 78 a 88", "De 89 a 98"])

# %%
df
# Out:
#         Unnamed: 0  Edad Identificador de la mujer  \
# 0                0    32           0100003.01.1.02
# 1                1    74           0100003.02.1.02
# 2                2    70           0100003.03.1.03
# 3                3    24           0100003.05.1.02
# 4                4    61           0100004.01.1.02
# ...            ...   ...                       ...
# 770884      770884    64           3260787.14.1.02
# 770885      770885    40           3260787.15.1.02
# 770886      770886    78           3260787.16.1.01
# 770887      770887    69           3260787.17.1.02
# 770888      770888    18           3260787.18.1.03
#
#         Identificador de vivienda seleccionada  \
# 0                                    100003.01
# 1                                    100003.02
# 2                                    100003.03
# 3                                    100003.05
# 4                                    100004.01
# ...                                        ...
# ...

# %% [markdown]
# Mujeres que no trabajan

# %%
labno = df[df['Situación laboral'] == 'No']
labno
# Out:
#         Unnamed: 0  Edad Identificador de la mujer  \
# 1                1    74           0100003.02.1.02
# 2                2    70           0100003.03.1.03
# 7                7    90           0100004.05.1.01
# 8                8    74           0100013.01.1.02
# 9                9    73           0100013.03.1.02
# ...            ...   ...                       ...
# 770880      770880    80           3260787.07.1.01
# 770881      770881    38           3260787.08.1.02
# 770886      770886    78           3260787.16.1.01
# 770887      770887    69           3260787.17.1.02
# 770888      770888    18           3260787.18.1.03
#
#         Identificador de vivienda seleccionada  \
# 1                                    100003.02
# 2                                    100003.03
# 7                                    100004.05
# 8                                    100013.01
# 9                                    100013.03
# ...                                        ...
# ...

# %%
autono = labno[labno['Autonomía para usar los recursos monetarios en lo que se desee'] == 'Sí']
autono
# Out:
#         Unnamed: 0  Edad Identificador de la mujer  \
# 8                8    74           0100013.01.1.02
# 9                9    73           0100013.03.1.02
# 13              13    75           0100032.02.1.01
# 14              14    77           0100032.03.1.02
# 15              15    32           0100032.04.1.02
# ...            ...   ...                       ...
# 770857      770857    18           3260770.17.1.03
# 770862      770862    42           3260779.04.1.02
# 770872      770872    28           3260779.18.1.02
# 770873      770873    75           3260779.19.1.01
# 770888      770888    18           3260787.18.1.03
#
#         Identificador de vivienda seleccionada  \
# 8                                    100013.01
# 9                                    100013.03
# 13                                   100032.02
# 14                                   100032.03
# 15                                   100032.04
# ...                                        ...
# ...

# %%
valuesi = autono[autono.value == 'Sí']

# %%
valuesi
# Out:
#         Unnamed: 0  Edad Identificador de la mujer  \
# 9                9    73           0100013.03.1.02
# 68              68    58           0100091.02.1.01
# 72              72    78           0100094.01.1.01
# 81              81    86           0100099.05.1.01
# 107            107    75           0100117.04.1.01
# ...            ...   ...                       ...
# 768937      768937    48           3201804.06.1.02
# 769023      769023    65           3201871.03.1.02
# 769328      769328    47           3202455.06.1.02
# 769907      769907    59           3260331.15.1.02
# 770072      770072    17           3260385.07.1.03
#
#         Identificador de vivienda seleccionada  \
# 9                                    100013.03
# 68                                   100091.02
# 72                                   100094.01
# 81                                   100099.05
# 107                                  100117.04
# ...                                        ...
# ...

# %%
valuesi1 = valuesi.groupby(['variable', 'rango_edad']).count().reset_index()

# %%
valuesi1
# Out:
#                                              variable  rango_edad  Unnamed: 0  \
# 0     Ingreso por beca escolar para sus hijos e hijas  De 15 a 25          84
# 1     Ingreso por beca escolar para sus hijos e hijas  De 26 a 36         351
# 2     Ingreso por beca escolar para sus hijos e hijas  De 37 a 46         397
# 3     Ingreso por beca escolar para sus hijos e hijas  De 47 a 56         114
# 4     Ingreso por beca escolar para sus hijos e hijas  De 57 a 67          21
# 5     Ingreso por beca escolar para sus hijos e hijas  De 68 a 77           3
# 6     Ingreso por beca escolar para sus hijos e hijas  De 78 a 88           0
# 7     Ingreso por beca escolar para sus hijos e hijas  De 89 a 98           1
# 8                     Ingreso por beca escolar propia  De 15 a 25         763
# 9                     Ingreso por beca escolar propia  De 26 a 36          49
# 10                    Ingreso por beca escolar propia  De 37 a 46          26
# ...

# %% [markdown]
# CSV para calcular ingresos otros de mujeres que no trabajan pero sí tienen autonomía

# %%
#valuesi1.to_csv('./valuesi.csv', encoding='latin-1')

# %% [markdown]
# Mujeres que no trabajan y NO tienen autonomía

# %%
autonoNO = labno[labno['Autonomía para usar los recursos monetarios en lo que se desee'] == 'No']
autonoNO
# Out:
#         Unnamed: 0  Edad Identificador de la mujer  \
# 1                1    74           0100003.02.1.02
# 2                2    70           0100003.03.1.03
# 7                7    90           0100004.05.1.01
# 11              11    21           0100019.04.1.04
# 17              17    75           0100036.01.1.01
# ...            ...   ...                       ...
# 770879      770879    26           3260787.06.1.02
# 770880      770880    80           3260787.07.1.01
# 770881      770881    38           3260787.08.1.02
# 770886      770886    78           3260787.16.1.01
# 770887      770887    69           3260787.17.1.02
#
#         Identificador de vivienda seleccionada  \
# 1                                    100003.02
# 2                                    100003.03
# 7                                    100004.05
# 11                                   100019.04
# 17                                   100036.01
# ...                                        ...
# ...

# %%
valuesip = autonoNO[autonoNO.value == 'Sí']

# %%
valuesno = valuesip.groupby(['variable', 'rango_edad']).count().reset_index()

# %% [markdown]
# CSV para calcular ingresos otros de mujeres que no trabajan pero si tienen autonomía

# %%
#valuesno.to_csv('./valuesno.csv')

# %% [markdown]
# Analizar ingreso por pareja/expareja, en mujeres con/sin autonomia, por rango de edad

# %%
result = pd.read_csv('./resultROBRT', encoding='latin-1')
result
# Out:
#         Unnamed: 0  Edad Identificador de la mujer  \
# 0                0    32           0100003.01.1.02
# 1                1    74           0100003.02.1.02
# 2                2    70           0100003.03.1.03
# 3                3    24           0100003.05.1.02
# 4                4    61           0100004.01.1.02
# ...            ...   ...                       ...
# 110122      110122    64           3260787.14.1.02
# 110123      110123    40           3260787.15.1.02
# 110124      110124    78           3260787.16.1.01
# 110125      110125    69           3260787.17.1.02
# 110126      110126    18           3260787.18.1.03
#
#         Identificador de vivienda seleccionada  \
# 0                                    100003.01
# 1                                    100003.02
# 2                                    100003.03
# 3                                    100003.05
# 4                                    100004.01
# ...                                        ...
# ...

# %%
result.loc[:,:'Cantidad de la aportación económica']
# Out:
#         Unnamed: 0  Edad Identificador de la mujer  \
# 0                0    32           0100003.01.1.02
# 1                1    74           0100003.02.1.02
# 2                2    70           0100003.03.1.03
# 3                3    24           0100003.05.1.02
# 4                4    61           0100004.01.1.02
# ...            ...   ...                       ...
# 110122      110122    64           3260787.14.1.02
# 110123      110123    40           3260787.15.1.02
# 110124      110124    78           3260787.16.1.01
# 110125      110125    69           3260787.17.1.02
# 110126      110126    18           3260787.18.1.03
#
#         Identificador de vivienda seleccionada  \
# 0                                    100003.01
# 1                                    100003.02
# 2                                    100003.03
# 3                                    100003.05
# 4                                    100004.01
# ...                                        ...
# ...

# %%
result.drop(result[result['Cantidad de la aportación económica'] == 999998.0].index, inplace = True)

# %%
result.drop(result[result['Cantidad de la aportación económica'] == 999997.0].index, inplace = True)

# %%
result.drop(result[result['Cantidad de la aportación económica'] == 999999.0].index, inplace = True)

# %%
result['rango_edad']=pd.cut(result.Edad, 8, precision=0, right=False, labels=["De 15 a 25", "De 26 a 36", "De 37 a 46", "De 47 a 56", "De 57 a 67", "De 68 a 77", "De 78 a 88", "De 89 a 98"])

# %%
result['rango_aporte']=pd.cut(result['Cantidad de la aportación económica'], 20, precision=0, right=False)

# %%
result.head()
# Out:
#    Unnamed: 0  Edad Identificador de la mujer  \
# 0           0    32           0100003.01.1.02
# 1           1    74           0100003.02.1.02
# 2           2    70           0100003.03.1.03
# 3           3    24           0100003.05.1.02
# 4           4    61           0100004.01.1.02
#
#    Identificador de vivienda seleccionada  Factor de expansión de la vivienda  \
# 0                               100003.01                                 113
# 1                               100003.02                                 113
# 2                               100003.03                                 113
# 3                               100003.05                                 113
# 4                               100004.01                                  78
#
#    Factor de expansión mujer Situación laboral  Salario  \
# 0                        113                Sí  10000.0
# 1                        113                No      NaN
# ...

# %% [markdown]
# cuántas mujeres que sufren violencia no trabajan y obtienen aporte económico por su pareja o ex pareja

# %%
result_labno = result[result['Situación laboral'] == 'No']

# %%
result_labno.head()
# Out:
#     Unnamed: 0  Edad Identificador de la mujer  \
# 1            1    74           0100003.02.1.02
# 2            2    70           0100003.03.1.03
# 7            7    90           0100004.05.1.01
# 11          11    21           0100019.04.1.04
# 13          13    75           0100032.02.1.01
#
#     Identificador de vivienda seleccionada  \
# 1                                100003.02
# 2                                100003.03
# 7                                100004.05
# 11                               100019.04
# 13                               100032.02
#
#     Factor de expansión de la vivienda  Factor de expansión mujer  \
# 1                                  113                        113
# 2                                  113                        227
# 7                                   78                         78
# 11                                 100                        201
# 13                                  89                         89
#
# ...

# %%
rob = pd.read_csv('./resultROBRT', encoding='latin-1')
rob
# Out:
#         Unnamed: 0  Edad Identificador de la mujer  \
# 0                0    32           0100003.01.1.02
# 1                1    74           0100003.02.1.02
# 2                2    70           0100003.03.1.03
# 3                3    24           0100003.05.1.02
# 4                4    61           0100004.01.1.02
# ...            ...   ...                       ...
# 110122      110122    64           3260787.14.1.02
# 110123      110123    40           3260787.15.1.02
# 110124      110124    78           3260787.16.1.01
# 110125      110125    69           3260787.17.1.02
# 110126      110126    18           3260787.18.1.03
#
#         Identificador de vivienda seleccionada  \
# 0                                    100003.01
# 1                                    100003.02
# 2                                    100003.03
# 3                                    100003.05
# 4                                    100004.01
# ...                                        ...
# ...

# %%
violid=pd.read_csv('./id_viol.csv', encoding='latin-1')
violid
# Out:
#         Unnamed: 0 Identificador de la mujer  \
# 0                0               01000031.12
# 1                1               01000032.12
# 2                2               01000033.13
# 3                3               01000035.12
# 4                4               01000041.12
# ...            ...                       ...
# 110122      110122             3260787.14.12
# 110123      110123             3260787.15.12
# 110124      110124             3260787.16.11
# 110125      110125             3260787.17.12
# 110126      110126             3260787.18.13
#
#         Avergonzamiento, ofensa, menosprecio o humillación  \
# 0                                                     4.0
# 1                                                     4.0
# 2                                                     4.0
# 3                                                     4.0
# 4                                                     4.0
# ...                                                   ...
# ...

# %%
#importar el csv limpio de la endireh que cree y nombre endireh final
finalmio = pd.read_csv('./ENDIREHfinal.csv', encoding='latin-1')
finalmio[:1]
# Out:
#    Unnamed: 0.1  Edad Identificador de la mujer  \
# 0             0    32           0100003.01.1.02
#
#    Identificador de vivienda seleccionada  Factor de expansión de la vivienda  \
# 0                               100003.01                                 113
#
#    Factor de expansión mujer  Situación laboral  Salario  \
# 0                        113                  1  10000.0
#
#    Autonomía para usar los recursos monetarios en lo que se desee  \
# 0                                                  1
#
#    Aporte económico por parte de la pareja o expareja de la informante  ...  \
# 0                                                1.0                    ...
#
#    Controlar  Amenaza con arma o de quemadura  \
# 0        4.0                              4.0
#
#    Amenaza de homicidio, suicidio o filicidio  \
# 0                                         4.0
#
#    Destruir u ocultar artículos personales o del hogar  Ignorar  \
# ...

# %%
finalmio1 = finalmio[finalmio['Aporte económico por parte de la pareja o expareja de la informante'] == 1.0]

# %%
finalmio2 = finalmio1[finalmio1['Autonomía para usar los recursos monetarios en lo que se desee'] == 1.0]

# %%
finalmio2 = finalmio2.loc[:,:'Intimidación y acecho psicológico por medios digitales o mediáticos en la relación de pareja']

# %%
finalmio2['rango_edad']=pd.cut(finalmio2.Edad, 8, precision=0, right=False, labels=["De 15 a 25", "De 26 a 36", "De 37 a 46", "De 47 a 56", "De 57 a 67", "De 68 a 77", "De 78 a 88", "De 89 a 98"])

# %%
finalmio3 = finalmio2[finalmio2['Situación laboral'] == 1]

# %%
finalmio3.head()
# Out:
#     Unnamed: 0.1  Edad Identificador de la mujer  \
# 0              0    32           0100003.01.1.02
# 16            16    50           0100032.05.1.02
# 25            25    27           0100037.04.1.02
# 30            30    51           0100044.05.1.02
# 43            43    52           0100054.03.1.02
#
#     Identificador de vivienda seleccionada  \
# 0                                100003.01
# 16                               100032.05
# 25                               100037.04
# 30                               100044.05
# 43                               100054.03
#
#     Factor de expansión de la vivienda  Factor de expansión mujer  \
# 0                                  113                        113
# 16                                  89                         89
# 25                                  87                         87
# 30                                  85                         85
# 43                                 103                        205
#
# ...

# %%
finalmio4 = finalmio3.loc[:,'Avergonzamiento, ofensa, menosprecio o humillación':]
finalmio4
# Out:
#         Avergonzamiento, ofensa, menosprecio o humillación  \
# 0                                                     4.0
# 16                                                    4.0
# 25                                                    4.0
# 30                                                    4.0
# 43                                                    4.0
# ...                                                   ...
# 110103                                                4.0
# 110107                                                4.0
# 110112                                                4.0
# 110114                                                4.0
# 110120                                                4.0
#
#         Invisibilización y falta de cariño  Afirmación de engaño  \
# 0                                      4.0                   4.0
# 16                                     4.0                   4.0
# 25                                     4.0                   4.0
# ...

# %%
finalmio5 = finalmio4.melt(id_vars='rango_edad')

# %%
finalmio5[:5]
# Out:
#    rango_edad                                           variable  value
# 0  De 26 a 36  Avergonzamiento, ofensa, menosprecio o humilla...    4.0
# 1  De 47 a 56  Avergonzamiento, ofensa, menosprecio o humilla...    4.0
# 2  De 26 a 36  Avergonzamiento, ofensa, menosprecio o humilla...    4.0
# 3  De 47 a 56  Avergonzamiento, ofensa, menosprecio o humilla...    4.0
# 4  De 47 a 56  Avergonzamiento, ofensa, menosprecio o humilla...    4.0

# %%
mujindependientes= finalmio5[finalmio5.value == 1.0]

# %%
#mujdependientes= finalmio5[finalmio5.value == 1.0]

# %%
#mujdependientess = mujdependientes.groupby(['rango_edad', 'variable']).count().reset_index()

# %%
#mujdependientess

# %%
#mujdependientess.to_csv('./mujdependientes.csv')

# %%
#mujdependientes.to_csv('./mujdependientes.csv')
#esta variable es sobre mujeres que NO TRABAJAN , NO TIENEN AUTONOMÍA Y RECIBEN INGRESO DE SU PAREJA. y se filtró por violencia prevalente

# %% [markdown]
# Nota: el código lo volví a correr cambiando la variante de la situación laboral para comparar mujeres que trabajan y dependen con su violencia psic, y mujeres que no trabajan y no dependen, contra la violencia psci que sufren ambos grupos

# %%
#result.columns[:5].tolist()+['Salario', 'Cantidad de la aportación económica']
#resultMelt2 = result.melt(
#  id_vars=result.columns[:10].tolist()
#)
#resultMelt2

# %%
#result_aporta1.astype(object)

# %%
#result_aporta1['rango_edad']= result_aporta1['rango_edad'].astype(object)

# %%
#result_aporta1.to_csv('./result_aporta1.csv')

# %%
mujindependientess = mujindependientes.groupby(['rango_edad', 'variable']).count().reset_index()

# %%
mujindependientess.to_csv('./mujindependientes.csv')
