# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('./ingresovm4.csv')
df
# Out:
#     Unnamed: 0             rango_s  rango_edad  \
# 0            0       [0.0, 7000.0)  De 15 a 25
# 1            1       [0.0, 7000.0)  De 26 a 36
# 2            2       [0.0, 7000.0)  De 37 a 46
# 3            3       [0.0, 7000.0)  De 47 a 56
# 4            4       [0.0, 7000.0)  De 57 a 67
# ..         ...                 ...         ...
# 77          77  [63000.0, 70070.0)  De 68 a 77
# 78          78  [63000.0, 70070.0)  De 78 a 88
# 79          79  [63000.0, 70070.0)  De 89 a 98
# 80     rango_s                 NaN         NaN
# 81  rango_edad                 NaN         NaN
#
#     Autonomía para usar los recursos monetarios en lo que se desee  variable  \
# 0                                              6020.0                 6020.0
# 1                                              9527.0                 9527.0
# 2                                             10023.0                10023.0
# 3                                              7122.0                 7122.0
# ...

# %%
alt.Chart(df).mark_bar().encode(
    x='value',
    y='rango_edad',
    color='rango_s'
)
# Out:
# alt.Chart(...)
